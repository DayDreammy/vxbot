# %%
import sqlite3
import pandas as pd
from pathlib import Path
from datetime import datetime, timedelta

def get_articles_by_title_keyword(keyword, db_path='data/message_monitor.db'):
    """
    通过标题关键词查询文章
    
    Parameters:
    -----------
    keyword : str
        要搜索的关键词
    db_path : str
        数据库路径
        
    Returns:
    --------
    pd.DataFrame
        包含查询结果的DataFrame
    """
    query = """
    SELECT 
        id,
        message_id,
        from_user,
        title,
        url,
        content,
        summary,
        created_at,
        processed,
        process_time,
        pdf_path
    FROM wechat_articles
    WHERE title LIKE ?
    ORDER BY created_at DESC
    """
    
    with sqlite3.connect(db_path) as conn:
        # 使用 LIKE 进行模糊匹配，%表示任意字符
        df = pd.read_sql_query(query, conn, params=[f'%{keyword}%'])
    
    # 转换时间列
    df['created_at'] = pd.to_datetime(df['created_at'])
    df['process_time'] = pd.to_datetime(df['process_time'])
    
    return df

# %%
# 使用示例
if __name__ == "__main__":
    # 搜索标题中包含"芯片"的文章
    keyword = "LEGO乐高招聘！"
    df = get_articles_by_title_keyword(keyword)
    
    print(f"找到包含关键词 '{keyword}' 的文章数量：{len(df)}")
    print("\n文章列表：")
    
    # 显示查询结果
    for _, row in df.iterrows():
        print(f"\n标题: {row['title']}")
        print(f"来源: {row['from_user']}")
        print(f"发布时间: {row['created_at']}")
        print(f"URL: {row['url']}")
        print(f"PDF路径: {row['pdf_path']}")
        # try:    
        #     print(f"内容: {row['content']}")
        # except:
        #     print(f"内容: ")
        print("-" * 80)
# Out:
# 找到包含关键词 'LEGO乐高招聘！' 的文章数量：2
#
# 文章列表：
#
# 标题: LEGO乐高招聘！带薪年假享受100%工资，员工折扣！
# 来源: gh_955ca91a83fc
# 发布时间: 2025-01-19 16:00:15
# URL: http://mp.weixin.qq.com/s?__biz=MzkyMTI0NTkyMg==&mid=2247745006&idx=1&sn=d3ff2ea80067a240c04c05a14b69f16e&chksm=c007a717c971ab85f0467304aabd927af2bde6267fd9f1ad122452ebc557f6de37ced2c84dd7&scene=0&xtrack=1#rd
# PDF路径: None
# --------------------------------------------------------------------------------
#
# 标题: LEGO乐高招聘！带薪年假享受100%工资，员工折扣！
# 来源: gh_760c4cb2ac58
# 发布时间: 2025-01-19 02:45:16
# URL: http://mp.weixin.qq.com/s?__biz=MzU1Njg3OTUyNw==&mid=2247913209&idx=1&sn=0a298adeef99cc8a1aae308c0bb9b431&chksm=fddbe148450c79bdbe0aafb0644419b91795ad07210e543dbc241e83c68cea769fe190aa8d24&scene=0&xtrack=1#rd
# PDF路径: None
# --------------------------------------------------------------------------------
